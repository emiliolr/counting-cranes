# %%
from PIL import Image
import numpy as np

# %% [markdown]
# # Old 2018 imagery

# %%
old_img_fp = '/Users/emiliolr/Desktop/Conservation Research/final_dataset/images/20180320_212957_600_9151.tif'
old_img = Image.open(old_img_fp).convert('RGB')
old_img
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F7A55DE8E90>

# %%
# Converting to RGB just repeats the single channel 3 times, isn't an issue b/c image is already 8-bit!
a = np.array(old_img)
np.sum(~(a[ : , : , 0] == a[ : , : , 1]))
# Out:
# 0

# %% [markdown]
# # New 2018 single parent images
#
# **Looks like these need to be converted from 32-bit to 8-bit!**

# %%
img_fp = '/Users/emiliolr/Desktop/counting-more-cranes/test_images/20180320_211401_170_2810.tif'
img = Image.open(img_fp)
print(img.size)
# Out:
# (1280, 720)

# %%
img
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/counting-more-cranes/lib/python3.7/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1217     try:
# -> 1218         rawmode, mode = _OUTMODES[mode]
#    1219     except KeyError as e:
#
# KeyError: 'F'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/envs/counting-more-cranes/lib/python3.7/site-packages/PIL/Image.py in _repr_png_(self)
#     673         try:
# --> 674             self.save(b, "PNG")
#     675         except Exception as e:
#
# ~/anaconda3/envs/counting-more-cranes/lib/python3.7/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2163         try:
# -> 2164             save_handler(self, fp, filename)
#    2165         finally:
#
# ...

# %%
img_arr = np.array(img)
img_arr.dtype
# Out:
# dtype('float32')
